# %% [markdown]
# # Classification : 2 Class

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### (1) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense
from keras.backend import clear_session
from keras.optimizers import Adam

# %% [markdown]
# * 학습곡선 함수

# %%
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### (2) 데이터로딩

# %%
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/titanic.3.csv"
data = pd.read_csv(path)
data.drop(['Age_scale1', 'AgeGroup', 'SibSp','Parch' ], axis = 1, inplace = True)
data.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare Embarked  Family
# 0         0       3    male  22.0   7.2500        S       2
# 1         1       1  female  38.0  71.2833        C       2
# 2         1       3  female  26.0   7.9250        S       1
# 3         1       1  female  35.0  53.1000        S       2
# 4         0       3    male  35.0   8.0500        S       1

# %% [markdown]
# ## 2.데이터 준비

# %% [markdown]
# Sex, Age, Fare 만 이용하여 Survived 를 예측하는 모델을 만들어 봅시다.

# %% [markdown]
# ### (1) 데이터 준비

# %%
target = 'Survived'
features = ['Sex', 'Age', 'Fare']
x = data.loc[:, features]
y = data.loc[:, target]

# %% [markdown]
# ### (2) 가변수화

# %%
x = pd.get_dummies(x, columns = ['Sex'], drop_first = True)
x.head()
# Out:
#     Age     Fare  Sex_male
# 0  22.0   7.2500         1
# 1  38.0  71.2833         0
# 2  26.0   7.9250         0
# 3  35.0  53.1000         0
# 4  35.0   8.0500         1

# %% [markdown]
# ### (3) 데이터분할

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.3, random_state = 20)

# %% [markdown]
# ### (4) Scaling

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ## 3.딥러닝1: 3개 feature

# %% [markdown]
# ### (1) 모델설계

# %%
nfeatures = x_train.shape[1]
nfeatures
# Out:
# 3

# %%
# 메모리 정리
clear_session()

# Sequential 모델 만들기
model = Sequential( Dense( 1 , input_shape = (nfeatures ,), activation= 'sigmoid') )

# 모델요약
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 4
#
# =================================================================
# Total params: 4 (16.00 Byte)
# Trainable params: 4 (16.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### (2) compile + 학습

# %%
model.compile(optimizer = Adam(learning_rate=0.01), loss = 'binary_crossentropy')

history = model.fit(x_train, y_train, epochs = 50, validation_split=0.2).history
# Out:
# Epoch 1/50
# 16/16 [==============================] - 1s 14ms/step - loss: 0.6799 - val_loss: 0.6486
# Epoch 2/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6342 - val_loss: 0.6119
# Epoch 3/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.6126 - val_loss: 0.5922
# Epoch 4/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5988 - val_loss: 0.5806
# Epoch 5/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.5897 - val_loss: 0.5711
# Epoch 6/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.5811 - val_loss: 0.5631
# Epoch 7/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5730 - val_loss: 0.5554
# Epoch 8/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5660 - val_loss: 0.5478
# Epoch 9/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5592 - val_loss: 0.5420
# Epoch 10/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5534 - val_loss: 0.5359
# Epoch 11/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5475 - val_loss: 0.5306
# Epoch 12/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5427 - val_loss: 0.5252
# Epoch 13/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.5380 - val_loss: 0.5214
# Epoch 14/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5334 - val_loss: 0.5170
# Epoch 15/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5299 - val_loss: 0.5128
# Epoch 16/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5263 - val_loss: 0.5097
# Epoch 17/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.5236 - val_loss: 0.5064
# Epoch 18/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5209 - val_loss: 0.5046
# Epoch 19/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.5178 - val_loss: 0.5021
# Epoch 20/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5157 - val_loss: 0.4999
# Epoch 21/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5140 - val_loss: 0.4974
# Epoch 22/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5119 - val_loss: 0.4959
# Epoch 23/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5103 - val_loss: 0.4947
# Epoch 24/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5088 - val_loss: 0.4938
# Epoch 25/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5075 - val_loss: 0.4921
# Epoch 26/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5061 - val_loss: 0.4915
# Epoch 27/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.5051 - val_loss: 0.4910
# Epoch 28/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5042 - val_loss: 0.4895
# Epoch 29/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5033 - val_loss: 0.4891
# Epoch 30/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5023 - val_loss: 0.4878
# Epoch 31/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5016 - val_loss: 0.4874
# Epoch 32/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.5009 - val_loss: 0.4872
# Epoch 33/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.5007 - val_loss: 0.4858
# Epoch 34/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4994 - val_loss: 0.4864
# Epoch 35/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4989 - val_loss: 0.4862
# Epoch 36/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4984 - val_loss: 0.4858
# Epoch 37/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4979 - val_loss: 0.4852
# Epoch 38/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4975 - val_loss: 0.4847
# Epoch 39/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4969 - val_loss: 0.4845
# Epoch 40/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4966 - val_loss: 0.4848
# Epoch 41/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4961 - val_loss: 0.4845
# Epoch 42/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4957 - val_loss: 0.4843
# Epoch 43/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4955 - val_loss: 0.4842
# Epoch 44/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4953 - val_loss: 0.4843
# Epoch 45/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4952 - val_loss: 0.4842
# Epoch 46/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4947 - val_loss: 0.4833
# Epoch 47/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4943 - val_loss: 0.4835
# Epoch 48/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4943 - val_loss: 0.4837
# Epoch 49/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4938 - val_loss: 0.4835
# Epoch 50/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4944 - val_loss: 0.4826

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(history)

# %% [markdown]
# ### (3) 예측 및 검증

# %%
pred = model.predict(x_val)

# activation이 sigmoid --> 0 ~ 1 사이의 확률값.
# 그러므로 cut-off value(보통 0.5)를 기준으로 잘라서 0과 1로 만들어 준다.
pred = np.where(pred >= .5, 1, 0) # cut-off value: 0.5
# Out:
# 9/9 [==============================] - 0s 4ms/step

# %%
print(classification_report(y_val, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.82       170
#            1       0.70      0.68      0.69        98
#
#     accuracy                           0.78       268
#    macro avg       0.76      0.76      0.76       268
# weighted avg       0.78      0.78      0.78       268

# %% [markdown]
# ## 4.딥러닝2 : 전체 feature
# * 이제 전체 데이터를 가지고 모델링을 시도해 보겠습니다.

# %% [markdown]
# ### (1) 데이터 전처리

# %% [markdown]
# * 데이터 준비

# %%
target = 'Survived'
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# %% [markdown]
# * 가변수화

# %%
cat_cols = ['Pclass','Sex', 'Embarked']
x = pd.get_dummies(x, columns = cat_cols, drop_first = True)

# %% [markdown]
# * 데이터분할

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.3, random_state = 20)

# %% [markdown]
# * 스케일링

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ### (2) 모델링

# %% [markdown]
# * 모델 설계

# %%
nfeatures = x_train.shape[1]

# %%
# 메모리 정리

clear_session()
# Sequential 모델
model =  Sequential(Dense(1, input_shape = (nfeatures,), activation = 'sigmoid'))

# 모델요약
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 9
#
# =================================================================
# Total params: 9 (36.00 Byte)
# Trainable params: 9 (36.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# * compile + 학습

# %%
model.compile(optimizer=Adam(learning_rate=0.01), loss='binary_crossentropy')
history = model.fit(x_train, y_train, epochs=50, validation_split=0.2).history
# Out:
# Epoch 1/50
# 16/16 [==============================] - 1s 20ms/step - loss: 0.6723 - val_loss: 0.5917
# Epoch 2/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6045 - val_loss: 0.5574
# Epoch 3/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5800 - val_loss: 0.5443
# Epoch 4/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5677 - val_loss: 0.5356
# Epoch 5/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.5582 - val_loss: 0.5277
# Epoch 6/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5503 - val_loss: 0.5219
# Epoch 7/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.5414 - val_loss: 0.5148
# Epoch 8/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.5347 - val_loss: 0.5092
# Epoch 9/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.5285 - val_loss: 0.5048
# Epoch 10/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5220 - val_loss: 0.4999
# Epoch 11/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5174 - val_loss: 0.4948
# Epoch 12/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5123 - val_loss: 0.4914
# Epoch 13/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5078 - val_loss: 0.4887
# Epoch 14/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5042 - val_loss: 0.4854
# Epoch 15/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5008 - val_loss: 0.4829
# Epoch 16/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4973 - val_loss: 0.4796
# Epoch 17/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4941 - val_loss: 0.4771
# Epoch 18/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4917 - val_loss: 0.4752
# Epoch 19/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4891 - val_loss: 0.4729
# Epoch 20/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4870 - val_loss: 0.4715
# Epoch 21/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4849 - val_loss: 0.4694
# Epoch 22/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4832 - val_loss: 0.4688
# Epoch 23/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4818 - val_loss: 0.4670
# Epoch 24/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4799 - val_loss: 0.4648
# Epoch 25/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4783 - val_loss: 0.4635
# Epoch 26/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4764 - val_loss: 0.4627
# Epoch 27/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4760 - val_loss: 0.4626
# Epoch 28/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4741 - val_loss: 0.4612
# Epoch 29/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4727 - val_loss: 0.4600
# Epoch 30/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4716 - val_loss: 0.4593
# Epoch 31/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4710 - val_loss: 0.4584
# Epoch 32/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4699 - val_loss: 0.4569
# Epoch 33/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4687 - val_loss: 0.4566
# Epoch 34/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4675 - val_loss: 0.4561
# Epoch 35/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4671 - val_loss: 0.4548
# Epoch 36/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4661 - val_loss: 0.4546
# Epoch 37/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4652 - val_loss: 0.4536
# Epoch 38/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4643 - val_loss: 0.4523
# Epoch 39/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4629 - val_loss: 0.4528
# Epoch 40/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4633 - val_loss: 0.4515
# Epoch 41/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4617 - val_loss: 0.4524
# Epoch 42/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4610 - val_loss: 0.4511
# Epoch 43/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4603 - val_loss: 0.4508
# Epoch 44/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4595 - val_loss: 0.4502
# Epoch 45/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4589 - val_loss: 0.4495
# Epoch 46/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4583 - val_loss: 0.4486
# Epoch 47/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4577 - val_loss: 0.4480
# Epoch 48/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4575 - val_loss: 0.4485
# Epoch 49/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4563 - val_loss: 0.4478
# Epoch 50/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4564 - val_loss: 0.4472

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(history)

# %% [markdown]
# * 예측 및 검증

# %%
pred = model.predict(x_val)

pred = np.where(pred > 0.5, 1, 0)
print(classification_report(y_val, pred))
# Out:
# 9/9 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.82       170
#            1       0.70      0.68      0.69        98
#
#     accuracy                           0.78       268
#    macro avg       0.76      0.76      0.76       268
# weighted avg       0.78      0.78      0.78       268

# %% [markdown]
# ----

# %% [markdown]
# ## 5.딥러닝3 : hidden layer
# * 이제 레이어를 추가해 보겠습니다.

# %% [markdown]
# ### (1) 모델 설계

# %%
n = x_train.shape[1]
n
# Out:
# 8

# %%
# 메모리 정리
clear_session()

# Sequential 모델
model3 = Sequential([ Dense( 4, input_shape = (n ,), activation = 'relu'),
                      Dense( 1, activation = 'sigmoid')])

# 모델요약
model3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 4)                 36
#
#  dense_1 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 41 (164.00 Byte)
# Trainable params: 41 (164.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### (2) compile + 학습

# %%
model3.compile( optimizer=Adam(learning_rate= 0.01), loss ='binary_crossentropy')
hist = model3.fit(x_train, y_train, epochs = 50, validation_split=.2 ).history
# Out:
# Epoch 1/50
# 16/16 [==============================] - 1s 14ms/step - loss: 0.6903 - val_loss: 0.6733
# Epoch 2/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6624 - val_loss: 0.6445
# Epoch 3/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6382 - val_loss: 0.6173
# Epoch 4/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.6049 - val_loss: 0.5757
# Epoch 5/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.5688 - val_loss: 0.5405
# Epoch 6/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5410 - val_loss: 0.5133
# Epoch 7/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5181 - val_loss: 0.4928
# Epoch 8/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5009 - val_loss: 0.4736
# Epoch 9/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4874 - val_loss: 0.4627
# Epoch 10/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4768 - val_loss: 0.4528
# Epoch 11/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4709 - val_loss: 0.4467
# Epoch 12/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4649 - val_loss: 0.4426
# Epoch 13/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4620 - val_loss: 0.4380
# Epoch 14/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4587 - val_loss: 0.4361
# Epoch 15/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4567 - val_loss: 0.4350
# Epoch 16/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4558 - val_loss: 0.4305
# Epoch 17/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4560 - val_loss: 0.4283
# Epoch 18/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4543 - val_loss: 0.4296
# Epoch 19/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4521 - val_loss: 0.4270
# Epoch 20/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4521 - val_loss: 0.4258
# Epoch 21/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4519 - val_loss: 0.4261
# Epoch 22/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4527 - val_loss: 0.4247
# Epoch 23/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4495 - val_loss: 0.4238
# Epoch 24/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4481 - val_loss: 0.4225
# Epoch 25/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4463 - val_loss: 0.4236
# Epoch 26/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4456 - val_loss: 0.4248
# Epoch 27/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4457 - val_loss: 0.4233
# Epoch 28/50
# 16/16 [==============================] - 0s 17ms/step - loss: 0.4456 - val_loss: 0.4224
# Epoch 29/50
# 16/16 [==============================] - 0s 17ms/step - loss: 0.4442 - val_loss: 0.4192
# Epoch 30/50
# 16/16 [==============================] - 0s 18ms/step - loss: 0.4436 - val_loss: 0.4217
# Epoch 31/50
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4413 - val_loss: 0.4203
# Epoch 32/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4413 - val_loss: 0.4197
# Epoch 33/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4411 - val_loss: 0.4185
# Epoch 34/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4420 - val_loss: 0.4201
# Epoch 35/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4405 - val_loss: 0.4172
# Epoch 36/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4400 - val_loss: 0.4170
# Epoch 37/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4393 - val_loss: 0.4192
# Epoch 38/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4395 - val_loss: 0.4157
# Epoch 39/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4399 - val_loss: 0.4178
# Epoch 40/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4408 - val_loss: 0.4141
# Epoch 41/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4392 - val_loss: 0.4153
# Epoch 42/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4406 - val_loss: 0.4148
# Epoch 43/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4387 - val_loss: 0.4177
# Epoch 44/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4383 - val_loss: 0.4162
# Epoch 45/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4383 - val_loss: 0.4155
# Epoch 46/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4388 - val_loss: 0.4135
# Epoch 47/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4380 - val_loss: 0.4144
# Epoch 48/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4382 - val_loss: 0.4153
# Epoch 49/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4374 - val_loss: 0.4157
# Epoch 50/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4384 - val_loss: 0.4131

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(hist)

# %% [markdown]
# * 예측 및 검증

# %%
pred3 = model3.predict(x_val)
pred3 = np.where(pred3 >= 0.5, 1, 0)
# Out:
# 9/9 [==============================] - 0s 4ms/step

# %%
print(classification_report(y_val, pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.94      0.85       170
#            1       0.84      0.53      0.65        98
#
#     accuracy                           0.79       268
#    macro avg       0.81      0.74      0.75       268
# weighted avg       0.80      0.79      0.78       268

# %% [markdown]
# ### (3) 실습1

# %% [markdown]
# * 다음의 summary를 보고 모델을 설계하시오.
#
# | Layer (type) | Output Shape | 옵션 |
# | ---- | ---- | ---- |
# | dense (Dense) | (None, 16)  | node, input_shape, activation = 'relu' |
# | dense_1 (Dense) | (None, 1) | node, activation = 'sigmoid' |

# %%
#input_shape
n
# Out:
# 8

# %%
clear_session()
model4 = Sequential([Dense(16, input_shape=(n,), activation='relu'),
                     Dense(1, activation='sigmoid')
                     ])
model4.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                144
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 161 (644.00 Byte)
# Trainable params: 161 (644.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model4.compile(optimizer=Adam(learning_rate=0.01), loss='binary_crossentropy')
hist = model4.fit(x_train, y_train,  epochs = 50, validation_split=.2).history
# Out:
# Epoch 1/50
# 16/16 [==============================] - 1s 22ms/step - loss: 0.5811 - val_loss: 0.5138
# Epoch 2/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5204 - val_loss: 0.4778
# Epoch 3/50
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4879 - val_loss: 0.4561
# Epoch 4/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4647 - val_loss: 0.4395
# Epoch 5/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4475 - val_loss: 0.4385
# Epoch 6/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4396 - val_loss: 0.4266
# Epoch 7/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4330 - val_loss: 0.4251
# Epoch 8/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4282 - val_loss: 0.4203
# Epoch 9/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4298 - val_loss: 0.4142
# Epoch 10/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4243 - val_loss: 0.4117
# Epoch 11/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4197 - val_loss: 0.4119
# Epoch 12/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4176 - val_loss: 0.4092
# Epoch 13/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4164 - val_loss: 0.4119
# Epoch 14/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4149 - val_loss: 0.4091
# Epoch 15/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4125 - val_loss: 0.4090
# Epoch 16/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4099 - val_loss: 0.4124
# Epoch 17/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4090 - val_loss: 0.4037
# Epoch 18/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4075 - val_loss: 0.4093
# Epoch 19/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4063 - val_loss: 0.4079
# Epoch 20/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4039 - val_loss: 0.4040
# Epoch 21/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4047 - val_loss: 0.4030
# Epoch 22/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4051 - val_loss: 0.4102
# Epoch 23/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4072 - val_loss: 0.4090
# Epoch 24/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4038 - val_loss: 0.4068
# Epoch 25/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4009 - val_loss: 0.4042
# Epoch 26/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3993 - val_loss: 0.4097
# Epoch 27/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4027 - val_loss: 0.4038
# Epoch 28/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3988 - val_loss: 0.4089
# Epoch 29/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3986 - val_loss: 0.4107
# Epoch 30/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3967 - val_loss: 0.4060
# Epoch 31/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3985 - val_loss: 0.4114
# Epoch 32/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3982 - val_loss: 0.4092
# Epoch 33/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3955 - val_loss: 0.4072
# Epoch 34/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3953 - val_loss: 0.4095
# Epoch 35/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3926 - val_loss: 0.4152
# Epoch 36/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3962 - val_loss: 0.4113
# Epoch 37/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3965 - val_loss: 0.4168
# Epoch 38/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3914 - val_loss: 0.4046
# Epoch 39/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3929 - val_loss: 0.4063
# Epoch 40/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3922 - val_loss: 0.4157
# Epoch 41/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3919 - val_loss: 0.4128
# Epoch 42/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3917 - val_loss: 0.4076
# Epoch 43/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3910 - val_loss: 0.4143
# Epoch 44/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3899 - val_loss: 0.4128
# Epoch 45/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3880 - val_loss: 0.4113
# Epoch 46/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3890 - val_loss: 0.4077
# Epoch 47/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3883 - val_loss: 0.4182
# Epoch 48/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3886 - val_loss: 0.4154
# Epoch 49/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3879 - val_loss: 0.4125
# Epoch 50/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3904 - val_loss: 0.4135

# %%
dl_history_plot(hist)

# %%
pred4 = model4.predict(x_val)
pred4 = np.where(pred4 >= 0.5, 1, 0)
print(classification_report(y_val, pred4))
# Out:
# 9/9 [==============================] - 0s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.79      0.89      0.84       170
#            1       0.75      0.59      0.66        98
#
#     accuracy                           0.78       268
#    macro avg       0.77      0.74      0.75       268
# weighted avg       0.78      0.78      0.77       268

# %% [markdown]
# ### (4) 실습2

# %% [markdown]
# * 다음의 summary를 보고 모델을 설계하시오.
#
# | Layer (type) | Output Shape |  옵션 |
# | ---- | ---- | ---- |
# | dense (Dense) | (None, 16) |  node, input_shape, activation = 'relu' |
# | dense_1 (Dense) | (None, 8) |  node, activation = 'relu'  |
# | dense_2 (Dense) | (None, 1) |  node, activation = 'sigmoid'  |

# %%
clear_session()
model5 = Sequential([Dense(16, input_shape=(n, ), activation='relu'),
                     Dense(8, activation='relu'),
                     Dense(1, activation='sigmoid')])
model5.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                144
#
#  dense_1 (Dense)             (None, 8)                 136
#
#  dense_2 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 289 (1.13 KB)
# Trainable params: 289 (1.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model5.compile(optimizer=Adam(learning_rate=0.01), loss='binary_crossentropy')
hist = model5.fit(x_train, y_train, epochs=50, validation_split=.2).history
# Out:
# Epoch 1/50
# 16/16 [==============================] - 3s 24ms/step - loss: 0.6515 - val_loss: 0.5953
# Epoch 2/50
# 16/16 [==============================] - 0s 15ms/step - loss: 0.5838 - val_loss: 0.5295
# Epoch 3/50
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5120 - val_loss: 0.4651
# Epoch 4/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4653 - val_loss: 0.4296
# Epoch 5/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4415 - val_loss: 0.4238
# Epoch 6/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4341 - val_loss: 0.4115
# Epoch 7/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4324 - val_loss: 0.4047
# Epoch 8/50
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4228 - val_loss: 0.4064
# Epoch 9/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4170 - val_loss: 0.4056
# Epoch 10/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4111 - val_loss: 0.4002
# Epoch 11/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4078 - val_loss: 0.4043
# Epoch 12/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4001 - val_loss: 0.4010
# Epoch 13/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3993 - val_loss: 0.3937
# Epoch 14/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3934 - val_loss: 0.4034
# Epoch 15/50
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3917 - val_loss: 0.3964
# Epoch 16/50
# 16/16 [==============================] - 0s 17ms/step - loss: 0.3897 - val_loss: 0.3977
# Epoch 17/50
# 16/16 [==============================] - 0s 15ms/step - loss: 0.3925 - val_loss: 0.4094
# Epoch 18/50
# 16/16 [==============================] - 0s 15ms/step - loss: 0.3852 - val_loss: 0.3982
# Epoch 19/50
# 16/16 [==============================] - 0s 17ms/step - loss: 0.3872 - val_loss: 0.3942
# Epoch 20/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3836 - val_loss: 0.3914
# Epoch 21/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3786 - val_loss: 0.4038
# Epoch 22/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3851 - val_loss: 0.3859
# Epoch 23/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3777 - val_loss: 0.4020
# Epoch 24/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3739 - val_loss: 0.3851
# Epoch 25/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3777 - val_loss: 0.3891
# Epoch 26/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3717 - val_loss: 0.4006
# Epoch 27/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3688 - val_loss: 0.3947
# Epoch 28/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3711 - val_loss: 0.3931
# Epoch 29/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3680 - val_loss: 0.4022
# Epoch 30/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3723 - val_loss: 0.4213
# Epoch 31/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3672 - val_loss: 0.4038
# Epoch 32/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3643 - val_loss: 0.3941
# Epoch 33/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3617 - val_loss: 0.4061
# Epoch 34/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3636 - val_loss: 0.4020
# Epoch 35/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3646 - val_loss: 0.4143
# Epoch 36/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3661 - val_loss: 0.4007
# Epoch 37/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3649 - val_loss: 0.4052
# Epoch 38/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3637 - val_loss: 0.3971
# Epoch 39/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3579 - val_loss: 0.3917
# Epoch 40/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3651 - val_loss: 0.4359
# Epoch 41/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3711 - val_loss: 0.3956
# Epoch 42/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3590 - val_loss: 0.3968
# Epoch 43/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3562 - val_loss: 0.3918
# Epoch 44/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3577 - val_loss: 0.3943
# Epoch 45/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3577 - val_loss: 0.4104
# Epoch 46/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3526 - val_loss: 0.3910
# Epoch 47/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3583 - val_loss: 0.3958
# Epoch 48/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3526 - val_loss: 0.3903
# Epoch 49/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3505 - val_loss: 0.4023
# Epoch 50/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3532 - val_loss: 0.4148

# %%
dl_history_plot(hist)

# %%
pred5 = model5.predict(x_val)
pred5 = np.where(pred5 > 0.5, 1, 0)
print(classification_report(y_val, pred5))
# Out:
# 9/9 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84       170
#            1       0.73      0.67      0.70        98
#
#     accuracy                           0.79       268
#    macro avg       0.78      0.77      0.77       268
# weighted avg       0.79      0.79      0.79       268

# %% [markdown]
# ### (5) 실습3

# %% [markdown]
# * 이번에는 여러분이 원하는 대로 설계하고, 학습해 봅시다.
