# %% [markdown]
# # **성능관리**

# %% [markdown]
# ## **1.환경준비**

# %% [markdown]
# ### **(1) 라이브러리 로딩**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.backend import clear_session
from keras.optimizers import Adam
from keras.datasets import mnist

# %% [markdown]
# * 함수 만들기

# %%
# 학습곡선 함수
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### **(2) 데이터로딩**

# %% [markdown]
# * 데이터 로딩
#     * 과적합을 위한 예제 데이터입니다.
#     * target
#     * feature : 0 ~ 299

# %%
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/overfit_sample.csv"
data = pd.read_csv(path)
data.head()
# Out:
#    target      0      1      2      3      4      5      6      7      8  ...  \
# 0       1 -1.067 -1.114 -0.616  0.376  1.090  0.467 -0.422  0.460 -0.443  ...
# 1       0 -0.831  0.271  1.716  1.096  1.731 -0.197  1.904 -0.265  0.557  ...
# 2       0  0.099  1.390 -0.732 -1.065  0.005 -0.081 -1.450  0.317 -0.624  ...
# 3       1 -0.989 -0.916 -1.343  0.145  0.543  0.636  1.127  0.189 -0.118  ...
# 4       0  0.811 -1.509  0.522 -0.360 -0.220 -0.959  0.334 -0.566 -0.656  ...
#
#      290    291    292    293    294    295    296    297    298    299
# 0  0.220 -0.339  0.254 -0.179  0.352  0.125  0.347  0.436  0.958 -0.824
# 1 -0.765 -0.735 -1.158  2.554  0.856 -1.506  0.462 -0.029 -1.932 -0.343
# 2 -1.311  0.799 -1.001  1.544  0.575 -0.309 -0.339 -0.148 -0.646  0.725
# 3 -1.370  1.093  0.596 -0.589 -0.649 -0.163 -0.958 -1.081  0.805  3.401
# 4 -0.178  0.718 -1.017  1.249 -0.596 -0.445  1.751  1.442 -0.393 -0.643
#
# [5 rows x 301 columns]

# %% [markdown]
# ## **2. Early Stopping**

# %% [markdown]
# ### **(1) 데이터 준비**

# %%
# 데이터분할 : x, y
target = 'target'
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# 데이터분할 : train, validation
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.2, random_state = 20)

# %%
# 스케일링
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ### **(2) 모델링**

# %%
# input_shape : feature 수 도출
nfeatures = x_train.shape[1]

# 메모리 정리
clear_session()

# Sequential 타입
model1 = Sequential( [Dense(128, input_shape = (nfeatures,), activation= 'relu'),
                      Dense(64, activation= 'relu'),
                      Dense(32, activation= 'relu'),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model1.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model1.fit(x_train, y_train, epochs = 100, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ### **(3) 미리 멈춤!(Early Stopping)**

# %% [markdown]
# #### 1) 함수 불러오기

# %%
from keras.callbacks import EarlyStopping

# %% [markdown]
# #### 2) 모델링 with early stopping

# %%
# 모델 선언
clear_session()

model2 = Sequential( [Dense(128, input_shape = (nfeatures,), activation= 'relu'),
                      Dense(64, activation= 'relu'),
                      Dense(32, activation= 'relu'),
                      Dense(1, activation= 'sigmoid')] )
model2.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# EarlyStopping 설정 ------------
min_de = 0.001
pat = 5 # 몇번 patient 할 건지

es = EarlyStopping(monitor = 'val_loss', min_delta = min_de, patience = pat)
# --------------------------------

# 학습
hist = model2.fit(x_train, y_train, epochs = 100, validation_split=0.2,
                  callbacks = [es]).history
dl_history_plot(hist)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 2s 43ms/step - loss: 0.7025 - val_loss: 0.6125
# Epoch 2/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5687 - val_loss: 0.5925
# Epoch 3/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.5776 - val_loss: 0.5976
# Epoch 4/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.5611 - val_loss: 0.5858
# Epoch 5/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5675 - val_loss: 0.5831
# Epoch 6/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5519 - val_loss: 0.5855
# Epoch 7/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5496 - val_loss: 0.5881
# Epoch 8/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5502 - val_loss: 0.5840
# Epoch 9/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5475 - val_loss: 0.5868
# Epoch 10/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.5340 - val_loss: 0.5875

# %% [markdown]
# ## **3.가중치 규제(Regularization)**

# %%
# 규제를 위해 필요한 함수 불러오기
from keras.regularizers import l1, l2

# %% [markdown]
# ### **(1) L1 규제**

# %%
# 메모리 정리
clear_session()

# Sequential 타입
model4 = Sequential( [Dense(128, input_shape = (nfeatures,), activation= 'relu',
                            kernel_regularizer = l1(0.01)),
                      Dense(64, activation= 'relu',
                            kernel_regularizer = l1(0.01)),
                      Dense(32, activation= 'relu',
                            kernel_regularizer = l1(0.01)),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model4.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model4.fit(x_train, y_train, epochs = 100, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ### **(2) L2 규제**

# %%
# 메모리 정리
clear_session()

# Sequential 타입
model5 = Sequential( [Dense(128, input_shape = (nfeatures,), activation= 'relu',
                            kernel_regularizer = l2(0.05)),
                      Dense(64, activation= 'relu',
                            kernel_regularizer = l2(0.05)),
                      Dense(32, activation= 'relu',
                            kernel_regularizer = l2(0.05)),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model5.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model5.fit(x_train, y_train, epochs = 100, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ## 4.[참조]Dropout

# %%
from keras.layers import Dropout

# %% [markdown]
# ### **(1) 적용 전**

# %%
# input_shape : feature 수 도출
nfeatures = x_train.shape[1]

# 메모리 정리
clear_session()

# Sequential 타입
model1 = Sequential( [Dense(128, input_shape = (nfeatures,), activation= 'relu'),
                      Dense(64, activation= 'relu'),
                      Dense(32, activation= 'relu'),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model1.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model1.fit(x_train, y_train, epochs = 100, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ### **(2) 적용 후**

# %%
# 메모리 정리
clear_session()

# Sequential 타입
model3 = Sequential( [Dense(128, input_shape = (nfeatures,), activation= 'relu'),
                      Dropout(0.4),
                      Dense(64, activation= 'relu'),
                      Dropout(0.4),
                      Dense(32, activation= 'relu'),
                      Dropout(0.4),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model3.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model3.fit(x_train, y_train, epochs = 50, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ## 5.모델 저장하기

# %% [markdown]
# ### (1) 모델 저장하기
#
# * model.save(‘파일이름.h5’)
#     * 딥러닝 모델의 메소드로 .save가 제공됩니다.
#     * 파일이름.h5 파일이 저장됩니다. (h5 파일 포맷 : 하둡파일 형식)

# %%
model1.save('hanky.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# * 저장된 파일은 왼쪽 '파일'탭에서 확인 가능
# * 파일을 다운로드 받을 수 있다.

# %% [markdown]
# ### (2) 모델 로딩하기
#
# * load_model 함수는 별도로 불러와야 합니다.
# * 경로를 맞춰주고 h5 파일을 읽어오면 그대로 사용 가능합니다.

# %%
from keras.models import load_model
model2 = load_model('hanky.h5')

# %% [markdown]
# * 불러온 모델 사용하기

# %%
pred2 = model2.predict(x_val) # x_val은 학습할 때 data 구조가 같아야함
# Out:
# 2/2 [==============================] - 0s 4ms/step

# %%
pred2_1 = np.where(pred2 > .5, 1, 0)

# %%
print(accuracy_score(y_val,pred2_1))
print('-'*60)
print(confusion_matrix(y_val, pred2_1))
print('-'*60)
print(classification_report(y_val, pred2_1))
# Out:
# 0.7
# ------------------------------------------------------------
# [[32  3]
#  [12  3]]
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.91      0.81        35
#            1       0.50      0.20      0.29        15
#
#     accuracy                           0.70        50
#    macro avg       0.61      0.56      0.55        50
# weighted avg       0.66      0.70      0.65        50

# %% [markdown]
# ### (3) 중간 체크포인트에 모델 저장하기

# %% [markdown]
# * 폴더 정리 : 위에서 저장한 파일들 제거하기

# %%
import os

def delete_h5_files(directory):
    for filename in os.listdir(directory):
        if filename.endswith(".h5"):
            file_path = os.path.join(directory, filename)
            try:
                os.remove(file_path)
                print(f"Deleted: {file_path}")
            except Exception as e:
                print(f"Error deleting {file_path}: {e}")

# 삭제할 디렉토리 지정
directory_to_delete_from = "/content/"

# 확장자가 .h5인 파일 삭제
delete_h5_files(directory_to_delete_from)
# Out:
# Deleted: /content/035.h5
# Deleted: /content/045.h5
# Deleted: /content/014.h5
# Deleted: /content/037.h5
# Deleted: /content/029.h5
# Deleted: /content/033.h5
# Deleted: /content/007.h5
# Deleted: /content/025.h5
# Deleted: /content/021.h5
# Deleted: /content/027.h5
# Deleted: /content/003.h5
# Deleted: /content/030.h5
# Deleted: /content/001.h5
# Deleted: /content/034.h5
# Deleted: /content/028.h5
# Deleted: /content/049.h5
# Deleted: /content/023.h5
# Deleted: /content/004.h5
# Deleted: /content/017.h5
# Deleted: /content/hanky.h5
# Deleted: /content/002.h5
# Deleted: /content/016.h5
# Deleted: /content/013.h5
# Deleted: /content/038.h5
# Deleted: /content/015.h5
# Deleted: /content/005.h5
# Deleted: /content/024.h5
# Deleted: /content/026.h5
# Deleted: /content/043.h5
# Deleted: /content/020.h5
# Deleted: /content/006.h5
# Deleted: /content/009.h5
# Deleted: /content/022.h5

# %% [markdown]
# #### 1) 체크포인트 함수 불러오기

# %%
from keras.callbacks import ModelCheckpoint

# %% [markdown]
# #### 2) 모델링 체크포인트 저장

# %% [markdown]
# * 모델 선언

# %%
# input_shape : feature 수 도출
nfeatures = x_train.shape[1]

# 메모리 정리
clear_session()

# Sequential 타입
model1 = Sequential( [Dense(64, input_shape = (nfeatures,), activation= 'relu'),
                      Dense(32, activation= 'relu'),
                      Dense(16, activation= 'relu'),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model1.compile(optimizer= Adam(learning_rate = 0.0001), loss='binary_crossentropy')

# %% [markdown]
# * 체크포인트 저장
#     * 아래 코드에서 ModelCheckpoint 콜백은 검증 데이터의 정확도(val_accuracy)를 기준으로 모델 저장
#     * 모델의 성능이 이전에 저장된 모델보다 향상될 때만 저장되도록 save_best_only=True로 설정
#     * 또한, verbose=1로 설정하면 모델이 저장될 때마다 콘솔에 메시지가 표시됨.

# %%
cp_path = '/content/{epoch:03d}.h5'
mcp = ModelCheckpoint(cp_path, monitor='val_loss', verbose = 1, save_best_only=True)

# 학습
hist = model1.fit(x_train, y_train, epochs = 50, validation_split=.2, callbacks=[mcp]).history
# Out:
# Epoch 1/50
# 1/5 [=====>........................] - ETA: 4s - loss: 0.6876
# Epoch 1: val_loss improved from inf to 0.66842, saving model to /content/001.h5
# 5/5 [==============================] - 1s 49ms/step - loss: 0.6781 - val_loss: 0.6684
# Epoch 2/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6813
# Epoch 2: val_loss improved from 0.66842 to 0.65475, saving model to /content/002.h5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.6645 - val_loss: 0.6547
# Epoch 3/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6420
# Epoch 3: val_loss improved from 0.65475 to 0.64096, saving model to /content/003.h5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6508 - val_loss: 0.6410
# Epoch 4/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6410
# Epoch 4: val_loss improved from 0.64096 to 0.62882, saving model to /content/004.h5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6350 - val_loss: 0.6288
# Epoch 5/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6167
# Epoch 5: val_loss improved from 0.62882 to 0.61846, saving model to /content/005.h5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6193 - val_loss: 0.6185
# Epoch 6/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6232
# Epoch 6: val_loss improved from 0.61846 to 0.60823, saving model to /content/006.h5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6078 - val_loss: 0.6082
# Epoch 7/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6109
# Epoch 7: val_loss improved from 0.60823 to 0.60051, saving model to /content/007.h5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5940 - val_loss: 0.6005
# Epoch 8/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5965
# Epoch 8: val_loss improved from 0.60051 to 0.59462, saving model to /content/008.h5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5864 - val_loss: 0.5946
# Epoch 9/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5667
# Epoch 9: val_loss improved from 0.59462 to 0.59069, saving model to /content/009.h5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5789 - val_loss: 0.5907
# Epoch 10/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4962
# Epoch 10: val_loss improved from 0.59069 to 0.58781, saving model to /content/010.h5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5742 - val_loss: 0.5878
# Epoch 11/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5149
# Epoch 11: val_loss improved from 0.58781 to 0.58584, saving model to /content/011.h5
# 5/5 [==============================] - 0s 18ms/step - loss: 0.5710 - val_loss: 0.5858
# Epoch 12/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5926
# Epoch 12: val_loss improved from 0.58584 to 0.58460, saving model to /content/012.h5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5676 - val_loss: 0.5846
# Epoch 13/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4975
# Epoch 13: val_loss improved from 0.58460 to 0.58370, saving model to /content/013.h5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5664 - val_loss: 0.5837
# Epoch 14/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5055
# Epoch 14: val_loss improved from 0.58370 to 0.58331, saving model to /content/014.h5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5654 - val_loss: 0.5833
# Epoch 15/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4079
# Epoch 15: val_loss improved from 0.58331 to 0.58327, saving model to /content/015.h5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5647 - val_loss: 0.5833
# Epoch 16/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5140
# Epoch 16: val_loss improved from 0.58327 to 0.58316, saving model to /content/016.h5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5640 - val_loss: 0.5832
# Epoch 17/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5229
# Epoch 17: val_loss improved from 0.58316 to 0.58278, saving model to /content/017.h5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5631 - val_loss: 0.5828
# Epoch 18/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5924
# Epoch 18: val_loss did not improve from 0.58278
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5625 - val_loss: 0.5829
# Epoch 19/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4921
# Epoch 19: val_loss did not improve from 0.58278
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5622 - val_loss: 0.5829
# Epoch 20/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5508
# Epoch 20: val_loss did not improve from 0.58278
# 5/5 [==============================] - 0s 10ms/step - loss: 0.5614 - val_loss: 0.5829
# Epoch 21/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4546
# Epoch 21: val_loss did not improve from 0.58278
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5606 - val_loss: 0.5832
# Epoch 22/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5680
# Epoch 22: val_loss did not improve from 0.58278
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5603 - val_loss: 0.5832
# Epoch 23/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4667
# Epoch 23: val_loss did not improve from 0.58278
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5592 - val_loss: 0.5835
# Epoch 24/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4238
# Epoch 24: val_loss did not improve from 0.58278
# 5/5 [==============================] - 0s 8ms/step - loss: 0.5585 - val_loss: 0.5836
# Epoch 25/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7627
# Epoch 25: val_loss did not improve from 0.58278
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5585 - val_loss: 0.5833
# Epoch 26/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5110
# Epoch 26: val_loss did not improve from 0.58278
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5574 - val_loss: 0.5834
# Epoch 27/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5163
# Epoch 27: val_loss did not improve from 0.58278
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5565 - val_loss: 0.5831
# Epoch 28/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5536
# Epoch 28: val_loss improved from 0.58278 to 0.58261, saving model to /content/028.h5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5559 - val_loss: 0.5826
# Epoch 29/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4222
# Epoch 29: val_loss improved from 0.58261 to 0.58227, saving model to /content/029.h5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5556 - val_loss: 0.5823
# Epoch 30/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5484
# Epoch 30: val_loss improved from 0.58227 to 0.58171, saving model to /content/030.h5
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5547 - val_loss: 0.5817
# Epoch 31/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4900
# Epoch 31: val_loss improved from 0.58171 to 0.58145, saving model to /content/031.h5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5539 - val_loss: 0.5814
# Epoch 32/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5860
# Epoch 32: val_loss improved from 0.58145 to 0.58123, saving model to /content/032.h5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5532 - val_loss: 0.5812
# Epoch 33/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5788
# Epoch 33: val_loss did not improve from 0.58123
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5526 - val_loss: 0.5813
# Epoch 34/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4433
# Epoch 34: val_loss improved from 0.58123 to 0.58110, saving model to /content/034.h5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5521 - val_loss: 0.5811
# Epoch 35/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6677
# Epoch 35: val_loss improved from 0.58110 to 0.58064, saving model to /content/035.h5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5515 - val_loss: 0.5806
# Epoch 36/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5395
# Epoch 36: val_loss improved from 0.58064 to 0.58043, saving model to /content/036.h5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5507 - val_loss: 0.5804
# Epoch 37/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4561
# Epoch 37: val_loss did not improve from 0.58043
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5507 - val_loss: 0.5809
# Epoch 38/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6245
# Epoch 38: val_loss did not improve from 0.58043
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5495 - val_loss: 0.5809
# Epoch 39/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6247
# Epoch 39: val_loss did not improve from 0.58043
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5486 - val_loss: 0.5805
# Epoch 40/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6247
# Epoch 40: val_loss improved from 0.58043 to 0.58012, saving model to /content/040.h5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5478 - val_loss: 0.5801
# Epoch 41/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5421
# Epoch 41: val_loss improved from 0.58012 to 0.57983, saving model to /content/041.h5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5471 - val_loss: 0.5798
# Epoch 42/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5637
# Epoch 42: val_loss improved from 0.57983 to 0.57963, saving model to /content/042.h5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5467 - val_loss: 0.5796
# Epoch 43/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4507
# Epoch 43: val_loss did not improve from 0.57963
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5457 - val_loss: 0.5799
# Epoch 44/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5444
# Epoch 44: val_loss improved from 0.57963 to 0.57958, saving model to /content/044.h5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5447 - val_loss: 0.5796
# Epoch 45/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5081
# Epoch 45: val_loss improved from 0.57958 to 0.57923, saving model to /content/045.h5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5441 - val_loss: 0.5792
# Epoch 46/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5017
# Epoch 46: val_loss did not improve from 0.57923
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5441 - val_loss: 0.5795
# Epoch 47/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5957
# Epoch 47: val_loss did not improve from 0.57923
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5426 - val_loss: 0.5795
# Epoch 48/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4802
# Epoch 48: val_loss did not improve from 0.57923
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5419 - val_loss: 0.5793
# Epoch 49/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5031
# Epoch 49: val_loss improved from 0.57923 to 0.57886, saving model to /content/049.h5
# 5/5 [==============================] - 0s 21ms/step - loss: 0.5412 - val_loss: 0.5789
# Epoch 50/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4601
# Epoch 50: val_loss did not improve from 0.57886
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5405 - val_loss: 0.5790

# %%
# 학습결과 그래프
dl_history_plot(hist)
