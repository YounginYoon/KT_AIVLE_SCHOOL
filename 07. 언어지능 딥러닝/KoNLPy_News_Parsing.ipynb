# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
url = urlopen('https://www.etnews.com/20240416000341')
soup = BeautifulSoup(url, 'lxml')

title = soup.find('div', {'class': 'article_title'}).get_text(strip=True)
contents = soup.find('div', {'class': 'article_txt'}).get_text(strip=True)
print(title)
print(contents)
# Out:
# 태영건설, 대주주 100대1 무상감자…1조원 자본확충
# 기업재무구조개선(워크아웃)이 진행중인 태영건설에 1조원 규모의 자본 확충이 이뤄질 전망이다. 대주주 티와이홀딩스 등에 대해서는 100대 1 비율의 대규모 무상 감자를 제시했다.16일 금융권에 따르면 태영건설 주채권은행인 산업은행은 이날 채권단 18개사를 대상으로 운영위원회를 열고 실사결과와 이같은 내용을 담은 기업개선계획을 논의했다.산은이 마련한 기업개선계획 초안은 대주주가 출자전환과 영구채 전환 등을 통해 7000억원 가량을 투입하고, 채권단이 무담보채권 가운데 절반인 3000억원 가량을 출자하는 방식이다.우선 태영건설이 워크아웃에 돌입하기 전 모회사인 티와이홀딩스가 사모펀드 콜버그크래비스로버츠(KKR)로부터 차입해 대여한 4000억원을 100% 출자전환한다. 태영인더스트리 매각 자금 3300억원 역시 영구채로 전환해 자본을 확충하는 방향으로 가닥을 잡았다. 대주주 보유 채권 전액을 자본확충에 투입하는 셈이다. 3000억원 상당은 채권단이 보유한 무담보채권을 50%를 출자전환하는 방식으로 채권단의 피해를 최소화하기 위한 조건을 내걸었다.태영건설의 지난해 말 기준 자본총계는 마이너스 6356억원으로 완전 자본잠식 상태다. 1조원 가량의 자본확충을 이뤄져야지만 근본적인 완전자본잠식을 해소할 수 있을 것으로 관측하고 있다.대신 기존 대주주 주식은 크게 줄인다. 100대 1 비율 무상감자가 유력하다. 소액주주의 경우 2대 1 수준으로 감자한다. 대주주가 출자전환을 통해 다량의 유동성을 공급하는 만큼 기존 주식을 줄이더라도 티와이홀딩스 및 윤 회장 등 사주 일가의 전체 지분은 60% 안팎으로 상승할 것으로 관측된다. 다만 워크아웃 기간 동안 경영권 행사는 불가능하다.태영건설이 참여 중인 프로젝트파이낸싱(PF) 사업장 60곳에 대한 처리 방향도 이날 공개됐다. 본PF 사업장 40곳 중 상당수는 사업을 그대로 진행한다. 10곳 미만의 사업장만 시공사 교체 또는 청산(경공매)을 결정했다. 브릿지론 단계의 PF 사업장 20곳 가운데 19곳은 시공사 교체 또는 청산이 이뤄진다.산은 및 채권단은 이달 중으로 기업개선계획을 확정할 계획이다. 오는 18일에는 전체 채권단 600여곳을 대상으로 설명회를 개최한다. 이달 중 열리는 금융채권자 협의회 해당 안건을 부의해 채권단의 동의를 얻어 기업개선계획을 최종 의결하는 것이 목표다.설명회장 향하는 태영건설 채권단 (서울=연합뉴스) 신현우 기자 = 16일 오후 태영건설 주요 채권단 대상 설명회가 열린 서울 영등포구 여의도 KDB산업은행 본점에서 채권단 관계자들이 설명회장으로 향하고 있다. 2024.4.16 nowwego@yna.co.kr (끝)류근일 기자 ryuryu@etnews.com
