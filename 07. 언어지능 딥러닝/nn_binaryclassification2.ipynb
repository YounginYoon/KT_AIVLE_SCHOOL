# %%
import torch
# ===========================================
# 비선형 테스트
# ===========================================

x_train = torch.FloatTensor([[1,2],[2,3],[3,4],[4,4],[5,3],[6,2],[6,4]])
y_train = torch.FloatTensor([[0],[0],[0],[1],[1],[1],[0]])
optimizer = torch.optim.SGD([W,b], lr=0.01)

# 딥러닝의 1단계: 모델을 만듦
def H(x):
    return torch.sigmoid(torch.matmul(x, W) + b) # H(x) = sigmoid(x) + b

# 딥러닝의 2단계: w, b 학습을 한다. epochs=2000
for step in range(2000):
    cost = -torch.mean(y_train*torch.log(H(x_train)) + (1-y_train)*torch.log(1-H(x_train)))
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

# 딥러닝 3단계: 추론/테스트을 한다
print(H(x_train))
# Out:
# tensor([[0.1380],
#         [0.1436],
#         [0.1494],
#         [0.2885],
#         [0.6734],
#         [0.9130],
#         [0.6835]], grad_fn=<SigmoidBackward0>)
